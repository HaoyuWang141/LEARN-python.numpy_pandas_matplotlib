# %% [markdown]
# # Python数据分析

# %% [markdown]
# ## 基础知识

# %%
2+3
# Out:
# 5

# %% [markdown]
# 循环语句

# %%
for i in range(5): 
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [1, 2, 3]
x = np.array([[1, 2], [3, 4], [5, 6]])
plt.plot(x, y, '.-')
